# %%
from FinanceNetworks.data import get_data_for_har

# %%
df = get_data_for_har(num_tickers=10)
# Out:
# [preprocess_for_har] Skipping BRK.B: DataFrame is empty or too small after preprocessing.

# %%
df
# Out:
# {'NVDA':              Adj Close       Close        High         Low        Open  \
#  Date
#  2015-02-04    0.483731    0.504000    0.509750    0.499750    0.501250
#  2015-02-05    0.491649    0.512250    0.512500    0.504000    0.504500
#  2015-02-06    0.489490    0.510000    0.517750    0.507750    0.511750
#  2015-02-09    0.489010    0.509500    0.511000    0.503750    0.507000
#  2015-02-10    0.502687    0.523750    0.524000    0.507750    0.510000
#  ...                ...         ...         ...         ...         ...
#  2025-12-17  170.940002  170.940002  176.130005  170.309998  176.100006
#  2025-12-18  174.139999  174.139999  176.149994  171.820007  174.529999
#  2025-12-19  180.990005  180.990005  181.449997  176.339996  176.669998
#  2025-12-22  183.690002  183.690002  184.160004  182.350006  183.919998
#  2025-12-23  189.210007  189.210007  189.330002  182.899994  182.970001
#
#                 Volume   Returns        RV1       RV5      RV10  ...  log_RV10  \
# ...
